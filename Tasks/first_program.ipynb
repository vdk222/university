# %% [markdown]
# <a href="https://colab.research.google.com/github/vdk222/university/blob/main/tasks/first_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# hello MIIGAiK
